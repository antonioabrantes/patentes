# %%
# !pip install requests_html
# Out:
# ...
#   Created wheel for parse: filename=parse-1.19.0-py3-none-any.whl size=24591 sha256=95fc29ebeead2eec70fe0a9c3cb6ccff8b2833fa54c9336bb3592809e03e2825
#   Stored in directory: d:\users\abrantes\appdata\local\pip\cache\wheels\d6\9c\58\ee3ba36897e890f3ad81e9b730791a153fce20caa4a8a474df
# Successfully built parse
# ...

# %%
# !pip install wget
# Out:
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=804dac21a7981e2c157147d0786b2b73a62958b47e6bc5df0a02f2aecf92a5cb
#   Stored in directory: d:\users\abrantes\appdata\local\pip\cache\wheels\04\5f\3e\46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
# Successfully built wget
# ...

# %%
# !pip install bs4

# %%
# !pip install requests

# %%
from requests_html import HTMLSession
import wget
from time import sleep

# %%
# para saber seu user agent vá no google e digite my user agent
headers = {
    'user-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36'
}

# %%
import nest_asyncio
nest_asyncio.apply()
dir = 'data'
s = HTMLSession()
with open('input.txt','r') as file:
    for url in file:
        r = s.get(url.strip(), headers=headers)
        page = rq.get(url)
        html = bs(page.text, 'lxml')
        hrefs = html.find_all("a")
        all_hrefs = []
        for href in hrefs:
            links = href.get("href")
            if '.pdf' in links:
                all_hrefs.append(links)

        pdf_link = all_hrefs[0]
        print(pdf_link)
        wget.download(url=pdf_link, out=dir)
# Out:
# https://patentimages.storage.googleapis.com/07/92/1e/38a832f1356371/JP6057972B2.pdf
# 100% [............................................................................] 311277 / 311277https://patentimages.storage.googleapis.com/a9/32/36/041feae5ed8b7c/JP6302983B2.pdf
# 100% [..........................................................................] 4506234 / 4506234https://patentimages.storage.googleapis.com/88/93/97/9a0b28fad713e9/US10682412.pdf
# 100% [..........................................................................] 5318342 / 5318342

# %%
import requests
import bs4
text= "geeksforgeeks"
url = 'https://google.com/search?q=' + text
request_result=requests.get( url )
soup = bs4.BeautifulSoup(request_result.text,"html.parser")
#print(soup)
heading_object=soup.find_all( 'h3' )
for info in heading_object:
    print(info.getText())
    print("------")
# Out:
# GeeksforGeeks
# ------
# GeeksforGeeks - YouTube
# ------
# GeeksforGeeks | LinkedIn
# ------
# GeeksforGeeks - Learn To Code – Apps on Google Play
# ------
# GeeksforGeeks (@geeks_for_geeks) • Instagram photos and videos
# ------
# Baixar GeeksforGeeks Official - Microsoft Store pt-BR
# ------
# “How GeeksforGeeks is making programming easier worldwide” | Mint
# ------

# %%
import requests as rq 
from bs4 import BeautifulSoup as bs
url = "https://patents.google.com/patent/JP6057972B2/en"
page = rq.get(url)
html = bs(page.text, 'lxml')
hrefs = html.find_all("a")
all_hrefs = []
for href in hrefs:
    links = href.get("href")
    if '.pdf' in links:
        all_hrefs.append(links)

pdf_link = all_hrefs[0]
print(pdf_link)
# Out:
# https://patentimages.storage.googleapis.com/07/92/1e/38a832f1356371/JP6057972B2.pdf

# %%
import requests 
import bs4 
city = "Imphal"
url = "https://google.com/search?q=weather+in+" + city
request_result = requests.get( url )
soup = bs4.BeautifulSoup( request_result.text, "html.parser" )
#print(soup)
temp = soup.find( "div" , class_='BNeawe' ).text # <div class="BNeawe iBp4i AP7Wnd"><div><div class="BNeawe iBp4i AP7Wnd">13°C</div>
print( temp )
# Out:
# 13°C

# %%
dir = 'data'
url = "https://github.com/cdqa-suite/cdQA/releases/download/bnpp_newsroom_v1.1/bnpp_newsroom-v1.1.csv"
wget.download(url=url, out=dir)
# Out:
# 100% [..........................................................................] 7025349 / 7025349
# 'data/bnpp_newsroom-v1.1.csv'

# %%
from requests_html import HTMLSession
import nest_asyncio

nest_asyncio.apply()

s = HTMLSession()
url="https://patents.google.com/patent/JP6057972B2/en"
r = s.get(url)
ht= r.text
print (ht)

#  <meta itemprop="type" content="patent">
#  <a href="https://patentimages.storage.googleapis.com/07/92/1e/38a832f1356371/JP6057972B2.pdf" itemprop="pdfLink">Download PDF</a>
#  <h2>Info</h2>
# Out:
# <!doctype html>
# <html lang="en">
#   <head>
#     <title>JP6057972B2 -
#   Semi-solid delivery excipients and pharmaceutical compositions
#
#       - Google Patents</title>
#
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <meta charset="UTF-8">
#     <meta name="referrer" content="origin-when-crossorigin">
#     <link rel="canonical" href="https://patents.google.com/patent/JP6057972B2/en">
#
#
#     <meta name="DC.type" content="patent">
#
#     <meta name="DC.title" content="
#   Semi-solid delivery excipients and pharmaceutical compositions
#
#      ">
#
#     <meta name="DC.date" content="2014-11-17" scheme="dateSubmitted">
#
#     <meta name="DC.description" content="">
#
#     <meta name="citation_patent_application_number" content="JP:2014232639A">
#
#     <meta name="citation_pdf_url" content="https://patentimages.storage.googleapis.com/07/92/1e/38a832f1356371/JP6057972B2.pdf">
#
# ...

# %%
from bs4 import BeautifulSoup
html = "<td class='val1'/><td col='1'/><td class='val2' />"
bsoup = BeautifulSoup(html, 'html.parser')
for td in bsoup.find_all('td'):
    if td.has_attr('class'):
        print(td['class'][0])
# Out:
# val1
# val2

# %%
from requests_html import HTMLSession
session = HTMLSession()
r = session.get("https://www.bbc.co.uk/news/technology-54448223")
date = r.html.find('time', first = True) # finding a "tag" called "time"
#print(date)  # you will have: <Element 'time' datetime='2020-10-07T11:41:22.000Z'>
# To get the text inside the "datetime" attribute use:
print(date.attrs['datetime'])
# Out:
# 2020-10-07T11:41:22.000Z
